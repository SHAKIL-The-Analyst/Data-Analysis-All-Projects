# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("F:/Skill Development- You Have No Access/Data Set/superstore_dataset2011-2015.csv", encoding='latin1')
df
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
df.tail()
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df['Order Date']=pd.to_datetime(df['Order Date'], format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df["Order Month"]=df['Order Date'].dt.month_name()
df["Order Month"]
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 51285    December
# 51286    December
# 51287    December
# 51288    December
# 51289    December
# Name: Order Month, Length: 51290, dtype: object

# %%
df["Order Day"]=df['Order Date'].dt.day_name()
df["Order Day"]
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#            ...
# 51285    Wednesday
# 51286    Wednesday
# 51287    Wednesday
# 51288    Wednesday
# 51289    Wednesday
# Name: Order Day, Length: 51290, dtype: object

# %%
df["Order Year"]=df['Order Date'].dt.year
df["Order Year"]
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: Order Year, Length: 51290, dtype: int32

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Month                 0
# Day                   0
# Year                  0
# Order Month           0
# Order Day             0
# Order Year            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Month             0
# Day               0
# Year              0
# Order Month       0
# Order Day         0
# Order Year        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Row ID                     Order Date   Postal Code  \
# count   9994.000000                           9994   9994.000000
# mean   36293.500000  2013-04-13 13:31:46.984190208  55190.379428
# min    31297.000000            2011-01-02 00:00:00   1040.000000
# 25%    33795.250000            2012-05-01 00:00:00  23223.000000
# 50%    36293.500000            2013-06-09 00:00:00  56430.500000
# 75%    38791.750000            2014-04-11 00:00:00  90008.000000
# max    41290.000000            2014-12-31 00:00:00  99301.000000
# std     2885.163629                            NaN  32063.693350
#
#               Sales     Quantity     Discount       Profit  Shipping Cost  \
# count   9994.000000  9994.000000  9994.000000  9994.000000    9994.000000
# mean     229.858001     3.789574     0.156203    28.656896      23.831678
# min        0.444000     1.000000     0.000000 -6599.978000       0.010000
# 25%       17.280000     2.000000     0.000000     1.728750       1.490000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Month', 'Day', 'Year',
#        'Order Month', 'Order Day', 'Order Year'],
#       dtype='object')

# %%
df.drop(['Row ID', 'Order ID', 'Customer ID', 'Postal Code'], axis=1,inplace=True)

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
cat=df.groupby("Category")['Profit'].sum().sort_values(ascending=False)

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Month', 'Day',
#        'Year', 'Order Month', 'Order Day', 'Order Year'],
#       dtype='object')

# %%
ax=sns.barplot(x=cat.index, y=cat.values, palette="Set1", saturation=1)
for bar in ax.containers:
    ax.bar_label(bar)
plt.xlabel('Category')  
plt.ylabel('Profit')
# Out:
# C:\Users\SHAKIL\AppData\Local\Temp\ipykernel_34736\992497357.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x=cat.index, y=cat.values, palette="Set1", saturation=1)
# Text(0, 0.5, 'Profit')

# %%
df['Region'].unique()
# Out:
# array(['West', 'Central', 'East', 'South'], dtype=object)

# %%
sns.barplot(x=cat2.index, y=cat2.values, palette="Set2", saturation=1)
plt.xlabel('Region')
plt.ylabel('Sales')
# Out:
# C:\Users\SHAKIL\AppData\Local\Temp\ipykernel_34736\2096733055.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cat2.index, y=cat2.values, palette="Set2", saturation=1)
# Text(0, 0.5, 'Sales')

# %%
cat2=df.groupby('Region')['Sales'].sum().sort_values(ascending=False).nlargest(5)

# %%
cat5=df.groupby('State')['Sales'].sum().sort_values(ascending=False).nlargest(5)
cat5
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Name: Sales, dtype: float64

# %%
sns.barplot(x=cat5.index, y=cat5.values, palette="Set3", saturation=1)
plt.ylabel("Total Sales")
# Out:
# C:\Users\SHAKIL\AppData\Local\Temp\ipykernel_34736\1208809072.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cat5.index, y=cat5.values, palette="Set3", saturation=1)
# Text(0, 0.5, 'Total Sales')

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Month', 'Day',
#        'Year', 'Order Month', 'Order Day', 'Order Year'],
#       dtype='object')

# %%
month_sales=df.groupby('Order Month')['Sales'].sum().sort_values(ascending=False).nlargest(5)

# %%
sns.barplot(x=month_sales.index, y=month_sales.values, palette="viridis", saturation=1.5)
plt.ylabel("Total Sales")
# Out:
# C:\Users\SHAKIL\AppData\Local\Temp\ipykernel_34736\615352764.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month_sales.index, y=month_sales.values, palette="viridis", saturation=1.5)
# Text(0, 0.5, 'Total Sales')

# %%
day=df.groupby('Order Day')['Sales'].sum().sort_values(ascending=False)

# %%
sns.barplot(x=day.index, y=day.values, palette="inferno", saturation=1)
plt.ylabel("Total Sales")
# Out:
# C:\Users\SHAKIL\AppData\Local\Temp\ipykernel_34736\4060027805.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day.index, y=day.values, palette="inferno", saturation=1)
# Text(0, 0.5, 'Total Sales')

# %%
sns.lineplot(x=day.index, y=day.values)
# Out:
# <Axes: xlabel='Order Day'>

# %%
df
# Out:
#       Order Date Ship Date       Ship Mode      Customer Name      Segment  \
# 7     2011-01-02  3/2/2011     First Class       Liz Carlisle     Consumer
# 27    2011-01-03  5/3/2011  Standard Class     Vicky Freymann  Home Office
# 32    2011-01-03  6/3/2011    Second Class        Dave Brooks     Consumer
# 34    2011-01-03  7/3/2011  Standard Class   Giulietta Weimer     Consumer
# 36    2011-01-03  5/3/2011  Standard Class   Shahid Collister     Consumer
# ...          ...       ...             ...                ...          ...
# 51257 2014-12-31  6/1/2015  Standard Class        Chuck Clark  Home Office
# 51260 2014-12-31  4/1/2015  Standard Class  Patrick O'Donnell     Consumer
# 51281 2014-12-31  4/1/2015  Standard Class         Erica Bern    Corporate
# 51285 2014-12-31  4/1/2015  Standard Class         Erica Bern    Corporate
# 51289 2014-12-31  4/1/2015  Standard Class      Jill Matthias     Consumer
#
# ...

# %%
popular_product= df['Product Name'].value_counts(ascending= False).nlargest(5)
popular_product
# Out:
# Product Name
# Staples                                       227
# Avery Non-Stick Binders                        20
# KI Adjustable-Height Table                     18
# Storex Dura Pro Binders                        17
# Situations Contoured Folding Chairs, 4/Set     15
# Name: count, dtype: int64

# %%
ax=sns.barplot(x = popular_product.index, y = popular_product.values)
for bar in ax.containers:
    ax.bar_label(bar)
plt.ylabel('count')
plt.xticks(rotation=90, ha="left")
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Staples'),
#   Text(1, 0, 'Avery Non-Stick Binders'),
#   Text(2, 0, 'KI Adjustable-Height Table'),
#   Text(3, 0, 'Storex Dura Pro Binders'),
#   Text(4, 0, 'Situations Contoured Folding Chairs, 4/Set')])
