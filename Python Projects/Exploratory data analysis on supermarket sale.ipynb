# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("F:/Skill Development- You Have No Access/Data Set/supermarket_sales - Sheet1.csv",parse_dates=['Date'])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 764  787-87-2010      A     Yangon        Member    Male
# 739  805-86-0265      A     Yangon        Normal    Male
# 304  396-90-2219      B   Mandalay        Normal  Female
# 174  414-12-7047      B   Mandalay        Normal    Male
# 456  710-46-4433      B   Mandalay        Member  Female
# 693  196-01-2849      C  Naypyitaw        Member  Female
# 756  785-96-0615      B   Mandalay        Member  Female
# 206  672-51-8681      C  Naypyitaw        Member  Female
# 890  389-70-2397      C  Naypyitaw        Normal  Female
# 446  235-46-8343      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 764       Health and beauty       55.50         4  11.1000  233.1000
# 739      Home and lifestyle       93.96         9  42.2820  887.9220
# 304  Electronic accessories       14.96         8   5.9840  125.6640
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sns.countplot(x='Branch', data= df, palette='Set1',saturation=1)
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
 df['Branch'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
 df['Branch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Branch'>

# %%
sns.countplot(x='Payment', data= df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
df['Payment'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Payment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment'>

# %%
plt.figure(figsize=(3,4))
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
sns.distplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.histplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Count'>

# %%
sns.histplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Count'>

# %%
sns.boxplot(df['cogs'])
# Out:
# <Axes: ylabel='cogs'>

# %%
sns.scatterplot(x='cogs', y= 'Rating', data=df)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
sns.scatterplot(x='gross income', y= 'Rating', data=df)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False)
# Out:
# Branch
# C    5265.1765
# A    5057.1605
# B    5057.0320
# Name: gross income, dtype: float64

# %%
sns.barplot(x='Branch', y='gross income', hue=df['City'], data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
df.groupby('Gender')['gross income'].sum().sort_values(ascending=False)
# Out:
# Gender
# Female    7994.425
# Male      7384.944
# Name: gross income, dtype: float64

# %%
sns.barplot(x='Gender', y= 'gross income', data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender', y= 'gross income', hue=df['Customer type'], data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.groupby('Product line')['gross income'].sum().sort_values(ascending=False)
# Out:
# Product line
# Food and beverages        2673.5640
# Sports and travel         2624.8965
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Home and lifestyle        2564.8530
# Health and beauty         2342.5590
# Name: gross income, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Product line', y= 'gross income', data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Product line', ylabel='gross income'>

# %%
df.groupby('Product line')['Unit price'].max().sort_values(ascending=False)
# Out:
# Product line
# Health and beauty         99.96
# Sports and travel         99.96
# Home and lifestyle        99.92
# Fashion accessories       99.89
# Food and beverages        99.79
# Electronic accessories    99.73
# Name: Unit price, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Product line', y= 'Unit price', data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Product line', ylabel='Unit price'>

# %%
pd.crosstab(df['City'], df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'], df['Payment']), annot=True)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
df.groupby('Product line')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product line
# Electronic accessories    971
# Food and beverages        952
# Sports and travel         920
# Home and lifestyle        911
# Fashion accessories       902
# Health and beauty         854
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Product line', y='Quantity', data=df, palette='Set1', saturation=1)
# Out:
# <Axes: xlabel='Product line', ylabel='Quantity'>

# %%
df.groupby('Product line')['Quantity'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>
